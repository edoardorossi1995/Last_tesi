# %% [markdown]
# # Setup

# %%
# %cd /Users/edoardorossi/Documents/GitHub/Last_tesi
PROJECT_PATH = '/Users/edoardorossi/Documents/GitHub/Last_tesi'
CTA30_PATH = '/Users/edoardorossi/Documents/Universita/Tesi/Tesi_GDrive'

import warnings
import pickle
import sys
import os
sys.path.insert(0, os.path.abspath('functions'))
sys.path.insert(0, os.path.abspath(''))
warnings.filterwarnings('ignore')
#from functions.pkl import store_data, load_data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from scipy.optimize import differential_evolution
import random
from collections import defaultdict
import time
import itertools
import joblib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten

def store_data(data, file_name):
    dbfile = open(file_name, 'ab')
    pickle.dump(data, dbfile)
    dbfile.close()
  
def load_data(file_name):
    dbfile = open(file_name, 'rb')
    db = pickle.load(dbfile)
    dbfile.close()
    return db


print("Libraries imported")
# Out:
# /Users/edoardorossi/Documents/GitHub/Last_tesi
# 2023-07-17 16:15:16.549143: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Libraries imported

# %% [markdown]
# # Import DF

# %%
cta30_def_path = os.path.join(CTA30_PATH, 'CTA30/DF_clean/clean_CTA_30_def.csv')  
df_def = pd.read_csv(cta30_def_path)

try:
    df = pd.read_csv(os.path.join(PROJECT_PATH, 'DQN_data/df.csv'))
    df_a = pd.read_csv(os.path.join(PROJECT_PATH, 'DQN_data/df_a.csv'))
    df_rew = pd.read_csv(os.path.join(PROJECT_PATH, 'DQN_data/df_rew.csv')) 
    
except:
    cta30_18_path = os.path.join(CTA30_PATH, 'CTA30/DF_clean/clean_CTA_30_2018.csv')
    cta30_19_path = os.path.join(CTA30_PATH, 'CTA30/DF_clean/clean_CTA_30_2019.csv')
    cta30_20_path = os.path.join(CTA30_PATH, 'CTA30/DF_clean/clean_CTA_30_2020.csv')
    cta30_21_path = os.path.join(CTA30_PATH, 'CTA30/DF_clean/clean_CTA_30_2021.csv')
    cta30_22_path = os.path.join(CTA30_PATH, 'CTA30/DF_clean/clean_CTA_30_2022.csv')

    df18= pd.read_csv(cta30_18_path)
    df19= pd.read_csv(cta30_19_path)
    df20= pd.read_csv(cta30_20_path)
    df21= pd.read_csv(cta30_21_path)
    df22= pd.read_csv(cta30_22_path)

    df_complete = pd.concat([df18, df19, df20, df21, df22], ignore_index=True)

    #drop le colonne 'F_M_FDBK_00', 'VLV_RAF_REG_00', 'VLV_SUR_REG_00' 
    df = df_complete.drop(['F_M_FDBK_00', 'VLV_RAF_REG_00', 'VLV_SUR_REG_00'], axis=1)
    # create df_a with only dropped columns
    df_a = df_complete[['F_M_FDBK_00', 'VLV_RAF_REG_00', 'VLV_SUR_REG_00']]


    df_a['VLV_RAF_REG_00'] = df_a['VLV_RAF_REG_00'].apply(lambda x: 1 if x>=0.5 else 0)
    df_a['VLV_SUR_REG_00'] = df_a['VLV_SUR_REG_00'].apply(lambda x: 1 if x>=0.5 else 0)

    df_a['VLV'] = 0 # colonna inizializzata a 0
    for i in range(len(df)):
        if df_a['VLV_RAF_REG_00'][i] == 0 and df_a['VLV_SUR_REG_00'][i] == 0:
            df_a.loc[i, 'VLV'] = 0
        elif df_a['VLV_RAF_REG_00'][i] == 0 and df_a['VLV_SUR_REG_00'][i] != 0:
            df_a.loc[i, 'VLV'] = -1
        elif df_a['VLV_RAF_REG_00'][i] != 0 and df_a['VLV_SUR_REG_00'][i] == 0:
            df_a.loc[i, 'VLV'] = 1

    df_a = df_a.drop(['VLV_RAF_REG_00', 'VLV_SUR_REG_00'], axis=1)

    df_rew = df_complete[['T_AMB_00', 'T_AMB_01', 'T_AMB_02', 'T_AMB_03', 'PW_ATT_M_00', 'T_M_SP_00']]

    #df_rew.to_csv(os.path.join(PROJECT_PATH, 'df_rew.csv'), index=False)     

    #print shapes of df and df_a and df_rew
    print('df shape: ', df.shape)
    print('df_a shape: ', df_a.shape)
    print('df_rew shape: ', df_rew.shape)

    df.to_csv(os.path.join(PROJECT_PATH, 'DQN_data/df.csv'), index=False)
    df_a.to_csv(os.path.join(PROJECT_PATH, 'DQN_data/df_a.csv'), index=False)
    df_rew.to_csv(os.path.join(PROJECT_PATH, 'DQN_data/df_rew.csv'), index=False)

# %%
#for each column in df_complete, plot the column
for col in df.columns:
    plt.figure()
    plt.plot(df[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# ## Normalization

# %%
path_scale_norm ='DQN_data/scaler_norm.pkl'
scaler_path = os.path.join(PROJECT_PATH, path_scale_norm)
print(scaler_path)
try: 
    scale_norm = load_data(scaler_path)
    df_norm = pd.DataFrame(scale_norm.transform(df), columns=df.columns)
    print("Normalization loaded")
except:
    print("Computing normalization")
    scale_norm = MinMaxScaler()
    df_norm = pd.DataFrame(scale_norm.fit_transform(df), columns=df.columns)
    store_data(scale_norm, scaler_path)

print("The dataset has", df_norm.shape[1], "columns after normalization")

path_pca_norm = 'DQN_data/pca_norm.pkl'
pca_model_path = os.path.join(PROJECT_PATH, path_pca_norm)
print(pca_model_path)
try:
    pca = load_data(pca_model_path)
    pca_norm = pd.DataFrame(pca.transform(df_norm))
    print("PCA loaded")
except:
    print("Computing PCA")
    pca = PCA(n_components=0.9)
    pca_norm = pd.DataFrame(pca.fit_transform(df_norm))
    store_data(pca, pca_model_path)
    print("PCA computed")
print("The dataset has", pca_norm.shape[1], "columns after PCA")

df_a_norm = pd.DataFrame(scale_norm.fit_transform(df_a), columns=df_a.columns)
# Out:
# /Users/edoardorossi/Documents/GitHub/Last_tesi/DQN_data/scaler_norm.pkl
# Computing normalization
# The dataset has 73 columns after normalization
# /Users/edoardorossi/Documents/GitHub/Last_tesi/DQN_data/pca_norm.pkl
# PCA loaded
# The dataset has 7 columns after PCA

# %% [markdown]
# ## Action - F: KMeans

# %%
DQN_path = 'DQN_data'
folder_name = 'action_f_fit_norm'
folder_path = os.path.join(PROJECT_PATH, DQN_path, folder_name)
os.makedirs(folder_path, exist_ok=True)
print(folder_path)

X = df_a_norm['F_M_FDBK_00'].values.reshape(-1,1)
k_min = 2
k_max = 10
step = 1


n_clusters_range = range(k_min,k_max+1,step)


for n_clusters in n_clusters_range:
    
    time_start = time.time()
    kmeans = KMeans(n_clusters=(n_clusters), init='k-means++', max_iter=300, n_init=10, random_state=0)
    # se il file è presente in PROJECT_PATH/DQN_path/folder_name non lo ricalcolo
    file_path = os.path.join(folder_path, f'kmeans_{n_clusters}.pkl')
    if os.path.isfile(file_path):
        print(f'kmeans_{n_clusters}.pkl already exists')
    else:
        kmeans.fit(X)
        print(file_path)
        with open(file_path, 'wb') as f:
            pickle.dump(kmeans, f)
        time_elapsed = time.time() - time_start
        print("KMeans with", n_clusters, "clusters computed in", time_elapsed, "seconds")
# Out:
# /Users/edoardorossi/Documents/GitHub/Last_tesi/DQN_data/action_f_fit_norm
# kmeans_2.pkl already exists
# kmeans_3.pkl already exists
# kmeans_4.pkl already exists
# kmeans_5.pkl already exists
# kmeans_6.pkl already exists
# kmeans_7.pkl already exists
# kmeans_8.pkl already exists
# kmeans_9.pkl already exists
# kmeans_10.pkl already exists

# %%
# ELBOW graph

from math import log
DQN_path = 'DQN_data'
folder_name = 'action_f_fit_norm'
folder_path = os.path.join(PROJECT_PATH, DQN_path, folder_name)
os.makedirs(folder_path, exist_ok=True)
file_list = os.listdir(folder_path)

def ordina_file_per_numero(nome_file):
    prefisso = "kmeans_"
    suffisso = ".pkl"
    numero_str = nome_file[len(prefisso):-len(suffisso)]
    numero = int(numero_str)
    return numero

# ordina la lista dei file utilizzando la funzione personalizzata
file_list_ordinata = sorted(file_list, key=ordina_file_per_numero)

x = []
y = []

print('lista file: \n', file_list_ordinata)

for i in range(len(file_list_ordinata)):

    # carica il file pkl
    with open(os.path.join(folder_path, file_list_ordinata[i]), 'rb') as f:
        modello = pickle.load(f)
    
    #esegui la fit su pca_norm 
    #modello.fit(X)

    #assegna alla variabile x il numero di cluster
    x.append(modello.n_clusters)

    #assegna alla variabile y il valore di wcss 
    y.append(modello.inertia_)

do_it = False
if do_it:
    # itera finché y non è ordinata in modo decrescente
    while y != sorted(y, reverse=True):
        remove_index = []
        for i in range(len(y)-1):
            if y[i] < y[i+1]:
                # salva l'indice i in una variabile e aggiungila alla lista degli indici da rimuovere
                remove_index.append(i)
        for i in remove_index:
            del x[i]
            del y[i]

elbow = 4
plt.plot(x,y)
plt.axvline(x=elbow, color='red')
plt.xlabel('Numero di cluster')
plt.ylabel('WCSS')
plt.title('Elbow Method norm - F_M_FDBK_00')
plt.show()

# stampa i centroidi del modello di clustering con 3 cluster
with open(os.path.join(folder_path, file_list_ordinata[elbow-2]), 'rb') as f:
    modello = pickle.load(f)
print(modello.cluster_centers_)
print(modello.labels_)
print(modello.inertia_)
print(modello.n_iter_)
print(modello.n_clusters)
print(modello.max_iter)
# Out:
# lista file:
#  ['kmeans_2.pkl', 'kmeans_3.pkl', 'kmeans_4.pkl', 'kmeans_5.pkl', 'kmeans_6.pkl', 'kmeans_7.pkl', 'kmeans_8.pkl', 'kmeans_9.pkl', 'kmeans_10.pkl']
# [[9.59514073e-06]
#  [4.96453165e-01]
#  [9.96612063e-01]
#  [3.39540659e-01]]
# [2 2 2 ... 0 0 0]
# 241.46819710986992
# 1
# 4
# 300

# %% [markdown]
# # DQN - Algorithm

# %% [markdown]
# ## Rete Neurale

# %%
########################### FUNZIONI  #############################

def tansig(x):
    return tf.keras.backend.tanh(x)

def state_reward(state):
    return -state['PW_ATT_M_00']

def state_action(state, action):
    state = state.to_numpy().reshape(1,-1) 
    action = action.to_numpy().reshape(1,-1)
    actions_df = pd.DataFrame(action, columns=['action_1', 'action_2'])
    state_df = pd.DataFrame(state, columns=df_norm.columns)
    s_a = pd.concat([state_df, actions_df], axis=1).to_numpy()
    s_a = torch.from_numpy(s_a).float()
    return s_a

def objective(next_state, x, model):
    s_a = state_action(next_state, x)
    q_next = q_torch_predict(s_a, model)   
    return q_next

def maximization(state, action_set, model):
    len_a1 = 4
    len_a2 = 3
    max_q = float('-inf')
    best_action = pd.Series([0,0])
    for i in range(len_a1):
        for j in range(len_a2):
            a0 = action_set[i][0][0]
            a1 = action_set[j][1]
            x0 = pd.Series([a0,a1])
            res = objective(state, x0, model)
            if res > max_q:
                max_q = res
                best_action = x0
                
    return best_action

def pred_best_q_next(next_state, action_set, model):
        best_action = maximization(next_state, action_set, model)
        s_a = state_action(next_state, best_action)
        q_next_ba = q_torch_predict(s_a, model)
        return q_next_ba

def q_torch_predict(s_a, model):
    model.eval() 
    with torch.no_grad():
        y_pred = model(s_a)
        q_ = y_pred.item()  
    return q_

def torch_fit(model, s_a, q_target):
    model.train()
    optimizer.zero_grad()
    y_pred = model(s_a)
    loss = criterion(y_pred, q_target)
    loss.backward()
    optimizer.step()

def save_model(model, model_path):
    torch.save(model.state_dict(), model_path)

def beta_decay(beta):
    if first_goal:
        beta *= 0.9
        if beta < 0.01:
            beta = 0.01
        print('beta: ', beta)
    return beta

def get_weights(model):
    weights_list = []
    for param in model.parameters():
        weights_list += param.tolist()
    return weights_list


def flatten_list(nested_list):
    flat_list = []
    for item in nested_list:
        if isinstance(item, list):
            flat_list.extend(flatten_list(item))
        else:
            flat_list.append(item)
    return flat_list

def get_weights_array(model):
    nested_weights = get_weights(model)
    weights_list = flatten_list(nested_weights)
    weights_list = np.array(weights_list)
    return weights_list

def fit_model_check_weights(model, s_a, q_target):
    initial_weights = get_weights_array(model)
    torch_fit(model, s_a, q_target)
    trained_weights = get_weights_array(model)
    w_diff = np.abs(trained_weights - initial_weights).max()
    return w_diff
    
############################# PARAMETERS ############################


my_df = df_norm.copy()  #   MODIFICARE - SOSTITUIRE CON TRAINING SET DA VALIDARE CON TEST SET
my_actions_df = df_a_norm.copy() # MODIFICARE - [...]

alpha = 0.001
gamma = 1
beta = 0.3

convergence_threshold = 1e-7
number_of_goals = 10
first_goal = False
convergence = False

# action space composition

f_clusterig_path = 'DQN_data/action_f_fit_norm'
folder_path = os.path.join(PROJECT_PATH, f_clusterig_path)
elbow = 4
try:
    with open(os.path.join(folder_path, 'kmeans_4.pkl'), 'rb') as f:
        action_f_model = pickle.load(f)
    print('action_f_model loaded')
except:
    X = my_actions_df['F_M_FDBK_00'].values.reshape(-1,1)
    action_f_model = KMeans(n_clusters=elbow, init='k-means++', max_iter=300, n_init=10, random_state=0)
    action_f_model.fit(X)
    with open(os.path.join(folder_path, 'kmeans_4.pkl'), 'wb') as f:
        pickle.dump(action_f_model, f)
    print('action_f_model computed')
F_M_centroids = action_f_model.cluster_centers_

vlv_values = my_actions_df['VLV'].unique()
action_set = list(itertools.product(F_M_centroids, vlv_values))
average_reward = random.uniform(-1, 1)
print('average reward: ', average_reward)

iteration = 0
n_save = 1000


########################## RETE NEURALE ##########################

#!pip install torch

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

state_size = my_df.shape[1]
input_size = state_size + 2
hidden_size = 15
output_size = 1



class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(NeuralNetwork, self).__init__()
        self.layers = nn.ModuleList()

        self.fc1 = nn.Linear(input_size, hidden_size)
        self.act1 = ExpActivation()
        self.fc2 = nn.Linear(hidden_size, output_size)
        self.act2 = LogActivation()

        self.layers.append(self.fc1)
        self.layers.append(self.fc2)
    
    
    def forward(self, x, T=1e-1):

        psi = self.compute_psi(x)

        x = self.fc1(x)
        x = self.act1((x - psi)/T)
        x = self.fc2(x)
        x = T*self.act2(x) + psi*T
        return x

    def compute_psi(self, x, T=1e-1):

        psi_values = []
        for layer in self.layers:
            x = layer(x)/T
            psi_values.append(x)
        assert len(psi_values) == len(self.layers)
        psi_float_values = []
        for tensor in psi_values:
            psi_float_values.extend(tensor.flatten().tolist())
        psi = max(psi_float_values)
        return psi


class ExpActivation(torch.nn.Module):
    def __init__(self):
        super(ExpActivation, self).__init__()
        
    def forward(self, x):
        return torch.exp(x)
    
class LogActivation(torch.nn.Module):
    def __init__(self):
        super(LogActivation, self).__init__()
    
    def forward(self, x):
        return torch.log(torch.exp(x))
    
model = NeuralNetwork(input_size, hidden_size, output_size)
criterion = nn.MSELoss()  # Mean Squared Error Loss
optimizer = optim.SGD(model.parameters(), lr=0.001)  # Stochastic Gradient Descent

# load model if exists
#folder_name = 'NN_model_torch'  # DQN standard - Possieri's NN
folder_name = 'NN_model_torch_av_re'    # DQN with average reward - Possieri's NN
model_path = os.path.join('/Users/edoardorossi/Documents/GitHub/Last_tesi/DQN_data', folder_name, 'torch_model_{}.pth'.format(hidden_size))
print('the path is: ', model_path)

if os.path.isfile(model_path):
    model.load_state_dict(torch.load(model_path))
    print('Torch model loaded')              

########################### TRAINING ##############################

while not convergence:

    time_start = time.time()

    data_idx = random.randint(0, len(my_df)-2) # per evitare di effettuare una transizione con next_state = NaN 
    
    state = my_df.iloc[data_idx]   # <class 'pandas.core.series.Series'>
    next_state = my_df.iloc[data_idx+1] # <class 'pandas.core.series.Series'>

    reward = state_reward(state)    #   <class 'numpy.float64'>
    average_reward = (1-beta) * average_reward + beta * reward 

    action = my_actions_df.iloc[data_idx]  # <class 'pandas.core.series.Series'>

    s_a = state_action(state, action)   # <class 'numpy.ndarray'>
 
    q_ = q_torch_predict(s_a, model) 
        
    q_next = pred_best_q_next(next_state, action_set, model)    # <class 'numpy.float64'>

    if folder_name == 'NN_model_torch_av_re':
        q = average_reward + gamma * q_next
    elif folder_name == 'NN_model_torch':
        q = q_ + alpha * (reward + gamma * q_next - q_)    # <class 'numpy.float64'>
    else:
        print('Error: folder_name not valid')
        break

    q_target = np.array([q])
    q_target = torch.from_numpy(q_target).float()   # <class 'torch.Tensor'> TORCH

    w_diff = fit_model_check_weights(model, s_a, q_target)
    
    if w_diff < convergence_threshold:
        number_of_goals -= 1
        first_goal = True
        print(f'Goal reached at iteration {iteration}')
        save_model(model, model_path)
        #beta_decay(beta)


    iteration += 1
    if iteration % n_save == 0:
        save_model(model, model_path)
        print(f'Model saved at iteration {iteration}')
        print(f'Iteration {iteration} completed in {time.time() - time_start} seconds')
        print('delta w: ', w_diff)

    
    if number_of_goals == 0:
        convergence = True
        print(f'Convergence reached at iteration {iteration}')
        save_model(model, model_path)
        print('Model saved')
        print(f'Iteration {iteration} completed in {time.time() - time_start} seconds')

    if torch.isinf(model.fc1.weight).any() or torch.isinf(model.fc1.bias).any() or torch.isinf(model.fc2.weight).any() or torch.isinf(model.fc2.bias).any():
        print('Inf in model weights or biases')
        break

    if torch.isnan(model.fc1.weight).any() or torch.isnan(model.fc1.bias).any() or torch.isnan(model.fc2.weight).any() or torch.isnan(model.fc2.bias).any():
        print('Nan in model weights or biases')
        break
# Out:
# action_f_model loaded
# average reward:  0.6753495000694678
# the path is:  /Users/edoardorossi/Documents/GitHub/Last_tesi/DQN_data/NN_model_torch_av_re/torch_model_15.pth
# Model saved at iteration 1000
# Iteration 1000 completed in 0.04111623764038086 seconds
# delta w:  5.717575550079346e-05
# Goal reached at iteration 1574
# Model saved at iteration 2000
# Iteration 2000 completed in 0.033178091049194336 seconds
# delta w:  6.0424208641052246e-05
# Model saved at iteration 3000
# Iteration 3000 completed in 0.03732490539550781 seconds
# delta w:  4.5627355575561523e-05
# Model saved at iteration 4000
# Iteration 4000 completed in 0.03529787063598633 seconds
# delta w:  5.6117773056030273e-05
# Model saved at iteration 5000
# Iteration 5000 completed in 0.03271985054016113 seconds
# delta w:  5.7190656661987305e-05
# Model saved at iteration 6000
# Iteration 6000 completed in 0.029185056686401367 seconds
# delta w:  6.195902824401855e-05
# Model saved at iteration 7000
# Iteration 7000 completed in 0.03571510314941406 seconds
# delta w:  5.415081977844238e-05
# Model saved at iteration 8000
# Iteration 8000 completed in 0.02796626091003418 seconds
# delta w:  5.1915645599365234e-05
# Model saved at iteration 9000
# Iteration 9000 completed in 0.0301513671875 seconds
# delta w:  7.396936416625977e-05
# Model saved at iteration 10000
# Iteration 10000 completed in 0.029994964599609375 seconds
# delta w:  6.669759750366211e-05
# Model saved at iteration 11000
# Iteration 11000 completed in 0.03935813903808594 seconds
# delta w:  6.937980651855469e-05
# Model saved at iteration 12000
# Iteration 12000 completed in 0.03175234794616699 seconds
# delta w:  5.370378494262695e-05
# Model saved at iteration 13000
# Iteration 13000 completed in 0.03137087821960449 seconds
# delta w:  5.2869319915771484e-05
# Model saved at iteration 14000
# Iteration 14000 completed in 0.03928518295288086 seconds
# delta w:  5.716085433959961e-05
# Model saved at iteration 15000
# Iteration 15000 completed in 0.03926396369934082 seconds
# delta w:  5.8650970458984375e-05
# Model saved at iteration 16000
# Iteration 16000 completed in 0.03792095184326172 seconds
# delta w:  5.888938903808594e-05
# Model saved at iteration 17000
# Iteration 17000 completed in 0.03209996223449707 seconds
# delta w:  5.7578086853027344e-05
# Model saved at iteration 18000
# Iteration 18000 completed in 0.035871028900146484 seconds
# delta w:  5.435943603515625e-05
# Model saved at iteration 19000
# Iteration 19000 completed in 0.02997899055480957 seconds
# delta w:  5.1856040954589844e-05
# Model saved at iteration 20000
# Iteration 20000 completed in 0.031232833862304688 seconds
# delta w:  5.2928924560546875e-05
# Model saved at iteration 21000
# Iteration 21000 completed in 0.030194997787475586 seconds
# delta w:  5.793571472167969e-05
# Model saved at iteration 22000
# Iteration 22000 completed in 0.030652999877929688 seconds
# delta w:  5.7578086853027344e-05
# Model saved at iteration 23000
# Iteration 23000 completed in 0.031158924102783203 seconds
# delta w:  5.1140785217285156e-05
# Model saved at iteration 24000
# Iteration 24000 completed in 0.028218984603881836 seconds
# delta w:  5.424022674560547e-05
# Model saved at iteration 25000
# Iteration 25000 completed in 0.036290884017944336 seconds
# delta w:  4.8279762268066406e-05
# Model saved at iteration 26000
# Iteration 26000 completed in 0.03672599792480469 seconds
# delta w:  6.496906280517578e-05
# Model saved at iteration 27000
# Iteration 27000 completed in 0.03227424621582031 seconds
# delta w:  4.780292510986328e-05
# Model saved at iteration 28000
# Iteration 28000 completed in 0.03271198272705078 seconds
# delta w:  4.303455352783203e-05
# Model saved at iteration 29000
# Iteration 29000 completed in 0.047122955322265625 seconds
# delta w:  7.212162017822266e-05
# Model saved at iteration 30000
# Iteration 30000 completed in 0.03333902359008789 seconds
# delta w:  4.971027374267578e-05
# Model saved at iteration 31000
# Iteration 31000 completed in 0.03293204307556152 seconds
# delta w:  6.210803985595703e-05
# Model saved at iteration 32000
# Iteration 32000 completed in 0.03160667419433594 seconds
# delta w:  6.413459777832031e-05
# Model saved at iteration 33000
# Iteration 33000 completed in 0.030279159545898438 seconds
# delta w:  5.3763389587402344e-05
# Model saved at iteration 34000
# Iteration 34000 completed in 0.05371904373168945 seconds
# delta w:  6.92605972290039e-05
# Model saved at iteration 35000
# Iteration 35000 completed in 0.03777003288269043 seconds
# delta w:  5.459785461425781e-05
# Model saved at iteration 36000
# Iteration 36000 completed in 0.04871797561645508 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 37000
# Iteration 37000 completed in 0.6080379486083984 seconds
# delta w:  6.0558319091796875e-05
# Model saved at iteration 38000
# Iteration 38000 completed in 0.056851863861083984 seconds
# delta w:  5.221366882324219e-05
# Model saved at iteration 39000
# Iteration 39000 completed in 0.033196210861206055 seconds
# delta w:  5.1021575927734375e-05
# Model saved at iteration 40000
# Iteration 40000 completed in 0.03484010696411133 seconds
# delta w:  4.887580871582031e-05
# Model saved at iteration 41000
# Iteration 41000 completed in 0.03325009346008301 seconds
# delta w:  5.888938903808594e-05
# Model saved at iteration 42000
# Iteration 42000 completed in 0.05559706687927246 seconds
# delta w:  4.744529724121094e-05
# Model saved at iteration 43000
# Iteration 43000 completed in 0.038736820220947266 seconds
# delta w:  5.1021575927734375e-05
# Model saved at iteration 44000
# Iteration 44000 completed in 0.03157520294189453 seconds
# delta w:  4.8160552978515625e-05
# Model saved at iteration 45000
# Iteration 45000 completed in 0.0359349250793457 seconds
# delta w:  5.459785461425781e-05
# Model saved at iteration 46000
# Iteration 46000 completed in 0.06694293022155762 seconds
# delta w:  5.817413330078125e-05
# Model saved at iteration 47000
# Iteration 47000 completed in 0.045165061950683594 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 48000
# Iteration 48000 completed in 0.038672685623168945 seconds
# delta w:  6.127357482910156e-05
# Model saved at iteration 49000
# Iteration 49000 completed in 0.055787086486816406 seconds
# delta w:  4.839897155761719e-05
# Model saved at iteration 50000
# Iteration 50000 completed in 0.0671079158782959 seconds
# delta w:  5.3882598876953125e-05
# Model saved at iteration 51000
# Iteration 51000 completed in 0.06742310523986816 seconds
# delta w:  5.3882598876953125e-05
# Model saved at iteration 52000
# Iteration 52000 completed in 0.06002402305603027 seconds
# delta w:  7.05718994140625e-05
# Model saved at iteration 53000
# Iteration 53000 completed in 0.08179211616516113 seconds
# delta w:  3.838539123535156e-05
# Model saved at iteration 54000
# Iteration 54000 completed in 0.1092379093170166 seconds
# delta w:  5.316734313964844e-05
# Model saved at iteration 55000
# Iteration 55000 completed in 0.05070209503173828 seconds
# delta w:  5.53131103515625e-05
# Model saved at iteration 56000
# Iteration 56000 completed in 0.43148303031921387 seconds
# delta w:  4.0531158447265625e-05
# Model saved at iteration 57000
# Iteration 57000 completed in 0.04755711555480957 seconds
# delta w:  5.412101745605469e-05
# Model saved at iteration 58000
# Iteration 58000 completed in 0.05022001266479492 seconds
# delta w:  6.67572021484375e-05
# Model saved at iteration 59000
# Iteration 59000 completed in 0.049796104431152344 seconds
# delta w:  5.078315734863281e-05
# Model saved at iteration 60000
# Iteration 60000 completed in 0.06244683265686035 seconds
# delta w:  5.8650970458984375e-05
# Model saved at iteration 61000
# Iteration 61000 completed in 0.040720224380493164 seconds
# delta w:  5.650520324707031e-05
# Model saved at iteration 62000
# Iteration 62000 completed in 0.05086469650268555 seconds
# delta w:  5.269050598144531e-05
# Model saved at iteration 63000
# Iteration 63000 completed in 0.10037899017333984 seconds
# delta w:  5.8650970458984375e-05
# Model saved at iteration 64000
# Iteration 64000 completed in 0.05933690071105957 seconds
# delta w:  5.2928924560546875e-05
# Model saved at iteration 65000
# Iteration 65000 completed in 0.06319427490234375 seconds
# delta w:  5.269050598144531e-05
# Model saved at iteration 66000
# Iteration 66000 completed in 0.04629015922546387 seconds
# delta w:  5.4836273193359375e-05
# Model saved at iteration 67000
# Iteration 67000 completed in 0.04995894432067871 seconds
# delta w:  4.839897155761719e-05
# Model saved at iteration 68000
# Iteration 68000 completed in 0.07484173774719238 seconds
# delta w:  5.888938903808594e-05
# Model saved at iteration 69000
# Iteration 69000 completed in 0.08355402946472168 seconds
# delta w:  5.0067901611328125e-05
# Model saved at iteration 70000
# Iteration 70000 completed in 0.05632805824279785 seconds
# delta w:  5.1021575927734375e-05
# Model saved at iteration 71000
# Iteration 71000 completed in 0.09882378578186035 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 72000
# Iteration 72000 completed in 0.17405486106872559 seconds
# delta w:  5.53131103515625e-05
# Model saved at iteration 73000
# Iteration 73000 completed in 0.07619023323059082 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 74000
# Iteration 74000 completed in 0.06331491470336914 seconds
# delta w:  4.673004150390625e-05
# Model saved at iteration 75000
# Iteration 75000 completed in 0.05949807167053223 seconds
# delta w:  5.1975250244140625e-05
# Model saved at iteration 76000
# Iteration 76000 completed in 0.06129598617553711 seconds
# delta w:  6.29425048828125e-05
# Model saved at iteration 77000
# Iteration 77000 completed in 0.04049515724182129 seconds
# delta w:  4.9114227294921875e-05
# Model saved at iteration 78000
# Iteration 78000 completed in 0.05420494079589844 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 79000
# Iteration 79000 completed in 0.0363771915435791 seconds
# delta w:  6.4849853515625e-05
# Model saved at iteration 80000
# Iteration 80000 completed in 0.06642460823059082 seconds
# delta w:  6.389617919921875e-05
# Model saved at iteration 81000
# Iteration 81000 completed in 0.03698992729187012 seconds
# delta w:  5.0067901611328125e-05
# Model saved at iteration 82000
# Iteration 82000 completed in 0.05013394355773926 seconds
# delta w:  6.771087646484375e-05
# Model saved at iteration 83000
# Iteration 83000 completed in 0.060060977935791016 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 84000
# Iteration 84000 completed in 0.04055905342102051 seconds
# delta w:  4.863739013671875e-05
# Model saved at iteration 85000
# Iteration 85000 completed in 0.046317100524902344 seconds
# delta w:  5.2928924560546875e-05
# Model saved at iteration 86000
# Iteration 86000 completed in 0.03851008415222168 seconds
# delta w:  5.435943603515625e-05
# Model saved at iteration 87000
# Iteration 87000 completed in 0.07843923568725586 seconds
# delta w:  5.5789947509765625e-05
# Model saved at iteration 88000
# Iteration 88000 completed in 0.0643620491027832 seconds
# delta w:  6.67572021484375e-05
# Model saved at iteration 89000
# Iteration 89000 completed in 0.16081809997558594 seconds
# delta w:  5.6743621826171875e-05
# Model saved at iteration 90000
# Iteration 90000 completed in 0.0386197566986084 seconds
# delta w:  6.341934204101562e-05
# Model saved at iteration 91000
# Iteration 91000 completed in 0.08385419845581055 seconds
# delta w:  5.53131103515625e-05
# Model saved at iteration 92000
# Iteration 92000 completed in 0.05854296684265137 seconds
# delta w:  6.914138793945312e-05
# Model saved at iteration 93000
# Iteration 93000 completed in 0.04953193664550781 seconds
# delta w:  5.054473876953125e-05
# Model saved at iteration 94000
# Iteration 94000 completed in 0.05324077606201172 seconds
# delta w:  5.7697296142578125e-05
# Model saved at iteration 95000
# Iteration 95000 completed in 0.07227206230163574 seconds
# delta w:  3.9577484130859375e-05
# Model saved at iteration 96000
# Iteration 96000 completed in 0.04386281967163086 seconds
# delta w:  4.863739013671875e-05
# Model saved at iteration 97000
# Iteration 97000 completed in 0.03543496131896973 seconds
# delta w:  5.245208740234375e-05
# Model saved at iteration 98000
# Iteration 98000 completed in 0.04681801795959473 seconds
# delta w:  5.2928924560546875e-05
# Model saved at iteration 99000
# Iteration 99000 completed in 0.06058812141418457 seconds
# delta w:  5.7697296142578125e-05
# Model saved at iteration 100000
# Iteration 100000 completed in 0.03832817077636719 seconds
# delta w:  5.7697296142578125e-05
# Model saved at iteration 101000
# Iteration 101000 completed in 0.033477067947387695 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 102000
# Iteration 102000 completed in 0.03325605392456055 seconds
# delta w:  6.437301635742188e-05
# Model saved at iteration 103000
# Iteration 103000 completed in 0.03308606147766113 seconds
# delta w:  6.0558319091796875e-05
# Model saved at iteration 104000
# Iteration 104000 completed in 0.023335933685302734 seconds
# delta w:  6.198883056640625e-05
# Model saved at iteration 105000
# Iteration 105000 completed in 0.02444911003112793 seconds
# delta w:  5.626678466796875e-05
# Model saved at iteration 106000
# Iteration 106000 completed in 0.025001049041748047 seconds
# delta w:  5.1021575927734375e-05
# Model saved at iteration 107000
# Iteration 107000 completed in 0.025238752365112305 seconds
# delta w:  5.1021575927734375e-05
# Model saved at iteration 108000
# Iteration 108000 completed in 0.023452043533325195 seconds
# delta w:  5.435943603515625e-05
# Model saved at iteration 109000
# Iteration 109000 completed in 0.023715972900390625 seconds
# delta w:  6.246566772460938e-05
# Model saved at iteration 110000
# Iteration 110000 completed in 0.02348494529724121 seconds
# delta w:  7.2479248046875e-05
# Model saved at iteration 111000
# Iteration 111000 completed in 0.024319887161254883 seconds
# delta w:  5.817413330078125e-05
# Model saved at iteration 112000
# Iteration 112000 completed in 0.023962974548339844 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 113000
# Iteration 113000 completed in 0.023958921432495117 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 114000
# Iteration 114000 completed in 0.0239560604095459 seconds
# delta w:  5.6743621826171875e-05
# Model saved at iteration 115000
# Iteration 115000 completed in 0.025606870651245117 seconds
# delta w:  5.7697296142578125e-05
# Model saved at iteration 116000
# Iteration 116000 completed in 0.03029012680053711 seconds
# delta w:  5.1021575927734375e-05
# Model saved at iteration 117000
# Iteration 117000 completed in 0.023419857025146484 seconds
# delta w:  5.817413330078125e-05
# Model saved at iteration 118000
# Iteration 118000 completed in 0.023973941802978516 seconds
# delta w:  5.7697296142578125e-05
# Model saved at iteration 119000
# Iteration 119000 completed in 0.023504018783569336 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 120000
# Iteration 120000 completed in 0.0236051082611084 seconds
# delta w:  5.1975250244140625e-05
# Model saved at iteration 121000
# Iteration 121000 completed in 0.030749797821044922 seconds
# delta w:  5.626678466796875e-05
# Model saved at iteration 122000
# Iteration 122000 completed in 0.02671217918395996 seconds
# delta w:  5.435943603515625e-05
# Model saved at iteration 123000
# Iteration 123000 completed in 0.02341318130493164 seconds
# delta w:  5.245208740234375e-05
# Model saved at iteration 124000
# Iteration 124000 completed in 0.06154322624206543 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 125000
# Iteration 125000 completed in 0.023693084716796875 seconds
# delta w:  6.628036499023438e-05
# Model saved at iteration 126000
# Iteration 126000 completed in 0.024060964584350586 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 127000
# Iteration 127000 completed in 0.02412700653076172 seconds
# delta w:  5.817413330078125e-05
# Model saved at iteration 128000
# Iteration 128000 completed in 0.02454996109008789 seconds
# delta w:  4.7206878662109375e-05
# Model saved at iteration 129000
# Iteration 129000 completed in 0.023740768432617188 seconds
# delta w:  7.62939453125e-05
# Model saved at iteration 130000
# Iteration 130000 completed in 0.024187088012695312 seconds
# delta w:  6.246566772460938e-05
# Model saved at iteration 131000
# Iteration 131000 completed in 0.02649688720703125 seconds
# delta w:  5.6743621826171875e-05
# Model saved at iteration 132000
# Iteration 132000 completed in 0.026816129684448242 seconds
# delta w:  5.4836273193359375e-05
# Model saved at iteration 133000
# Iteration 133000 completed in 0.026590824127197266 seconds
# delta w:  5.435943603515625e-05
# Model saved at iteration 134000
# Iteration 134000 completed in 0.039705753326416016 seconds
# delta w:  5.0067901611328125e-05
# Model saved at iteration 135000
# Iteration 135000 completed in 0.08666706085205078 seconds
# delta w:  5.1975250244140625e-05
# Model saved at iteration 136000
# Iteration 136000 completed in 0.040184736251831055 seconds
# delta w:  6.008148193359375e-05
# Model saved at iteration 137000
# Iteration 137000 completed in 0.0423581600189209 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 138000
# Iteration 138000 completed in 0.03801774978637695 seconds
# delta w:  7.43865966796875e-05
# Model saved at iteration 139000
# Iteration 139000 completed in 0.037697792053222656 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 140000
# Iteration 140000 completed in 0.039617061614990234 seconds
# delta w:  4.291534423828125e-05
# Model saved at iteration 141000
# Iteration 141000 completed in 0.05131816864013672 seconds
# delta w:  5.054473876953125e-05
# Model saved at iteration 142000
# Iteration 142000 completed in 0.06430697441101074 seconds
# delta w:  5.435943603515625e-05
# Model saved at iteration 143000
# Iteration 143000 completed in 0.037979841232299805 seconds
# delta w:  4.863739013671875e-05
# Model saved at iteration 144000
# Iteration 144000 completed in 0.04116201400756836 seconds
# delta w:  4.863739013671875e-05
# Model saved at iteration 145000
# Iteration 145000 completed in 0.03660869598388672 seconds
# delta w:  6.771087646484375e-05
# Model saved at iteration 146000
# Iteration 146000 completed in 0.041876792907714844 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 147000
# Iteration 147000 completed in 0.03796076774597168 seconds
# delta w:  6.29425048828125e-05
# Model saved at iteration 148000
# Iteration 148000 completed in 0.03942608833312988 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 149000
# Iteration 149000 completed in 0.03632998466491699 seconds
# delta w:  6.29425048828125e-05
# Model saved at iteration 150000
# Iteration 150000 completed in 0.037104129791259766 seconds
# delta w:  6.198883056640625e-05
# Model saved at iteration 151000
# Iteration 151000 completed in 0.03216695785522461 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 152000
# Iteration 152000 completed in 0.036985158920288086 seconds
# delta w:  5.817413330078125e-05
# Model saved at iteration 153000
# Iteration 153000 completed in 0.03327488899230957 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 154000
# Iteration 154000 completed in 0.049507856369018555 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 155000
# Iteration 155000 completed in 0.050795793533325195 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 156000
# Iteration 156000 completed in 0.03328990936279297 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 157000
# Iteration 157000 completed in 0.044406890869140625 seconds
# delta w:  3.814697265625e-05
# Model saved at iteration 158000
# Iteration 158000 completed in 0.043486833572387695 seconds
# delta w:  6.29425048828125e-05
# Model saved at iteration 159000
# Iteration 159000 completed in 0.04706287384033203 seconds
# delta w:  4.863739013671875e-05
# Model saved at iteration 160000
# Iteration 160000 completed in 0.04981398582458496 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 161000
# Iteration 161000 completed in 0.05650687217712402 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 162000
# Iteration 162000 completed in 0.034636735916137695 seconds
# delta w:  6.4849853515625e-05
# Model saved at iteration 163000
# Iteration 163000 completed in 0.03736281394958496 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 164000
# Iteration 164000 completed in 0.06767702102661133 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 165000
# Iteration 165000 completed in 0.031639814376831055 seconds
# delta w:  6.29425048828125e-05
# Model saved at iteration 166000
# Iteration 166000 completed in 0.033904075622558594 seconds
# delta w:  6.29425048828125e-05
# Model saved at iteration 167000
# Iteration 167000 completed in 0.03501105308532715 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 168000
# Iteration 168000 completed in 0.042613983154296875 seconds
# delta w:  5.245208740234375e-05
# Model saved at iteration 169000
# Iteration 169000 completed in 0.03325796127319336 seconds
# delta w:  5.245208740234375e-05
# Model saved at iteration 170000
# Iteration 170000 completed in 0.0352933406829834 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 171000
# Iteration 171000 completed in 0.03308224678039551 seconds
# delta w:  4.863739013671875e-05
# Model saved at iteration 172000
# Iteration 172000 completed in 0.03676295280456543 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 173000
# Iteration 173000 completed in 0.032740116119384766 seconds
# delta w:  5.245208740234375e-05
# Model saved at iteration 174000
# Iteration 174000 completed in 0.03163003921508789 seconds
# delta w:  5.53131103515625e-05
# Model saved at iteration 175000
# Iteration 175000 completed in 0.0319669246673584 seconds
# delta w:  6.008148193359375e-05
# Model saved at iteration 176000
# Iteration 176000 completed in 0.03465700149536133 seconds
# delta w:  3.719329833984375e-05
# Model saved at iteration 177000
# Iteration 177000 completed in 0.03373885154724121 seconds
# delta w:  4.863739013671875e-05
# Model saved at iteration 178000
# Iteration 178000 completed in 0.03987479209899902 seconds
# delta w:  6.198883056640625e-05
# Model saved at iteration 179000
# Iteration 179000 completed in 0.031844139099121094 seconds
# delta w:  5.435943603515625e-05
# Model saved at iteration 180000
# Iteration 180000 completed in 0.03054213523864746 seconds
# delta w:  6.008148193359375e-05
# Model saved at iteration 181000
# Iteration 181000 completed in 0.03444719314575195 seconds
# delta w:  5.435943603515625e-05
# Model saved at iteration 182000
# Iteration 182000 completed in 0.032553911209106445 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 183000
# Iteration 183000 completed in 0.032366037368774414 seconds
# delta w:  5.054473876953125e-05
# Model saved at iteration 184000
# Iteration 184000 completed in 0.030868053436279297 seconds
# delta w:  5.626678466796875e-05
# Model saved at iteration 185000
# Iteration 185000 completed in 0.03201484680175781 seconds
# delta w:  5.53131103515625e-05
# Model saved at iteration 186000
# Iteration 186000 completed in 0.03211212158203125 seconds
# delta w:  6.008148193359375e-05
# Model saved at iteration 187000
# Iteration 187000 completed in 0.033522844314575195 seconds
# delta w:  5.245208740234375e-05
# Model saved at iteration 188000
# Iteration 188000 completed in 0.07404685020446777 seconds
# delta w:  6.008148193359375e-05
# Model saved at iteration 189000
# Iteration 189000 completed in 0.04416394233703613 seconds
# delta w:  6.4849853515625e-05
# Model saved at iteration 190000
# Iteration 190000 completed in 0.045207977294921875 seconds
# delta w:  5.817413330078125e-05
# Model saved at iteration 191000
# Iteration 191000 completed in 0.13489079475402832 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 192000
# Iteration 192000 completed in 0.024415016174316406 seconds
# delta w:  6.008148193359375e-05
# Model saved at iteration 193000
# Iteration 193000 completed in 0.032106876373291016 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 194000
# Iteration 194000 completed in 0.02511119842529297 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 195000
# Iteration 195000 completed in 0.023905038833618164 seconds
# delta w:  6.389617919921875e-05
# Model saved at iteration 196000
# Iteration 196000 completed in 0.0318911075592041 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 197000
# Iteration 197000 completed in 0.024003028869628906 seconds
# delta w:  5.435943603515625e-05
# Model saved at iteration 198000
# Iteration 198000 completed in 0.028126001358032227 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 199000
# Iteration 199000 completed in 0.02836298942565918 seconds
# delta w:  6.008148193359375e-05
# Model saved at iteration 200000
# Iteration 200000 completed in 0.025586843490600586 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 201000
# Iteration 201000 completed in 0.03785896301269531 seconds
# delta w:  4.482269287109375e-05
# Model saved at iteration 202000
# Iteration 202000 completed in 0.023684978485107422 seconds
# delta w:  5.626678466796875e-05
# Model saved at iteration 203000
# Iteration 203000 completed in 0.023635149002075195 seconds
# delta w:  6.198883056640625e-05
# Model saved at iteration 204000
# Iteration 204000 completed in 0.024667739868164062 seconds
# delta w:  7.343292236328125e-05
# Model saved at iteration 205000
# Iteration 205000 completed in 0.026087045669555664 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 206000
# Iteration 206000 completed in 0.028692245483398438 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 207000
# Iteration 207000 completed in 0.04683399200439453 seconds
# delta w:  4.863739013671875e-05
# Model saved at iteration 208000
# Iteration 208000 completed in 0.02330303192138672 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 209000
# Iteration 209000 completed in 0.023714065551757812 seconds
# delta w:  6.29425048828125e-05
# Model saved at iteration 210000
# Iteration 210000 completed in 0.023897886276245117 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 211000
# Iteration 211000 completed in 0.029772043228149414 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 212000
# Iteration 212000 completed in 0.02877187728881836 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 213000
# Iteration 213000 completed in 0.03178715705871582 seconds
# delta w:  5.817413330078125e-05
# Model saved at iteration 214000
# Iteration 214000 completed in 0.02545022964477539 seconds
# delta w:  5.817413330078125e-05
# Model saved at iteration 215000
# Iteration 215000 completed in 0.02938699722290039 seconds
# delta w:  6.580352783203125e-05
# Model saved at iteration 216000
# Iteration 216000 completed in 0.030727148056030273 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 217000
# Iteration 217000 completed in 0.02673482894897461 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 218000
# Iteration 218000 completed in 0.02633190155029297 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 219000
# Iteration 219000 completed in 0.0301361083984375 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 220000
# Iteration 220000 completed in 0.03179216384887695 seconds
# delta w:  6.67572021484375e-05
# Model saved at iteration 221000
# Iteration 221000 completed in 0.03160595893859863 seconds
# delta w:  6.008148193359375e-05
# Model saved at iteration 222000
# Iteration 222000 completed in 0.0307009220123291 seconds
# delta w:  3.719329833984375e-05
# Model saved at iteration 223000
# Iteration 223000 completed in 0.03188204765319824 seconds
# delta w:  6.580352783203125e-05
# Model saved at iteration 224000
# Iteration 224000 completed in 0.04179263114929199 seconds
# delta w:  6.961822509765625e-05
# Model saved at iteration 225000
# Iteration 225000 completed in 0.042582035064697266 seconds
# delta w:  5.53131103515625e-05
# Model saved at iteration 226000
# Iteration 226000 completed in 0.030802011489868164 seconds
# delta w:  5.245208740234375e-05
# Model saved at iteration 227000
# Iteration 227000 completed in 0.030668973922729492 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 228000
# Iteration 228000 completed in 0.031067848205566406 seconds
# delta w:  4.482269287109375e-05
# Model saved at iteration 229000
# Iteration 229000 completed in 0.030766725540161133 seconds
# delta w:  5.054473876953125e-05
# Model saved at iteration 230000
# Iteration 230000 completed in 0.03291177749633789 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 231000
# Iteration 231000 completed in 0.032219886779785156 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 232000
# Iteration 232000 completed in 0.03533005714416504 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 233000
# Iteration 233000 completed in 0.030781269073486328 seconds
# delta w:  4.863739013671875e-05
# Model saved at iteration 234000
# Iteration 234000 completed in 0.02903127670288086 seconds
# delta w:  6.008148193359375e-05
# Model saved at iteration 235000
# Iteration 235000 completed in 0.029237031936645508 seconds
# delta w:  5.054473876953125e-05
# Model saved at iteration 236000
# Iteration 236000 completed in 0.03162407875061035 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 237000
# Iteration 237000 completed in 0.03285694122314453 seconds
# delta w:  4.00543212890625e-05
# Model saved at iteration 238000
# Iteration 238000 completed in 0.023353099822998047 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 239000
# Iteration 239000 completed in 0.02318263053894043 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 240000
# Iteration 240000 completed in 0.15366506576538086 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 241000
# Iteration 241000 completed in 0.023855209350585938 seconds
# delta w:  3.719329833984375e-05
# Model saved at iteration 242000
# Iteration 242000 completed in 0.026024818420410156 seconds
# delta w:  4.863739013671875e-05
# Model saved at iteration 243000
# Iteration 243000 completed in 0.024566173553466797 seconds
# delta w:  6.389617919921875e-05
# Model saved at iteration 244000
# Iteration 244000 completed in 0.024226665496826172 seconds
# delta w:  4.863739013671875e-05
# Model saved at iteration 245000
# Iteration 245000 completed in 0.023833751678466797 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 246000
# Iteration 246000 completed in 0.0237429141998291 seconds
# delta w:  3.910064697265625e-05
# Model saved at iteration 247000
# Iteration 247000 completed in 0.038407325744628906 seconds
# delta w:  4.38690185546875e-05
# Model saved at iteration 248000
# Iteration 248000 completed in 0.023290157318115234 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 249000
# Iteration 249000 completed in 0.026566028594970703 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 250000
# Iteration 250000 completed in 0.024203062057495117 seconds
# delta w:  4.291534423828125e-05
# Model saved at iteration 251000
# Iteration 251000 completed in 0.023373842239379883 seconds
# delta w:  6.008148193359375e-05
# Model saved at iteration 252000
# Iteration 252000 completed in 0.023366928100585938 seconds
# delta w:  4.863739013671875e-05
# Model saved at iteration 253000
# Iteration 253000 completed in 0.03659200668334961 seconds
# delta w:  5.054473876953125e-05
# Model saved at iteration 254000
# Iteration 254000 completed in 0.025209665298461914 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 255000
# Iteration 255000 completed in 0.025702953338623047 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 256000
# Iteration 256000 completed in 0.023936033248901367 seconds
# delta w:  3.719329833984375e-05
# Model saved at iteration 257000
# Iteration 257000 completed in 0.02420210838317871 seconds
# delta w:  5.054473876953125e-05
# Model saved at iteration 258000
# Iteration 258000 completed in 0.023977994918823242 seconds
# delta w:  5.054473876953125e-05
# Model saved at iteration 259000
# Iteration 259000 completed in 0.023424863815307617 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 260000
# Iteration 260000 completed in 0.04015707969665527 seconds
# delta w:  6.008148193359375e-05
# Model saved at iteration 261000
# Iteration 261000 completed in 0.02396392822265625 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 262000
# Iteration 262000 completed in 0.02435612678527832 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 263000
# Iteration 263000 completed in 0.024918079376220703 seconds
# delta w:  5.054473876953125e-05
# Model saved at iteration 264000
# Iteration 264000 completed in 0.024338960647583008 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 265000
# Iteration 265000 completed in 0.023930072784423828 seconds
# delta w:  6.580352783203125e-05
# Model saved at iteration 266000
# Iteration 266000 completed in 0.025616884231567383 seconds
# delta w:  6.4849853515625e-05
# Model saved at iteration 267000
# Iteration 267000 completed in 0.02408623695373535 seconds
# delta w:  6.008148193359375e-05
# Model saved at iteration 268000
# Iteration 268000 completed in 0.02654099464416504 seconds
# delta w:  4.863739013671875e-05
# Model saved at iteration 269000
# Iteration 269000 completed in 0.0238800048828125 seconds
# delta w:  4.863739013671875e-05
# Model saved at iteration 270000
# Iteration 270000 completed in 0.029141664505004883 seconds
# delta w:  6.580352783203125e-05
# Model saved at iteration 271000
# Iteration 271000 completed in 0.02342987060546875 seconds
# delta w:  3.719329833984375e-05
# Model saved at iteration 272000
# Iteration 272000 completed in 0.023831844329833984 seconds
# delta w:  5.054473876953125e-05
# Model saved at iteration 273000
# Iteration 273000 completed in 0.02365708351135254 seconds
# delta w:  5.435943603515625e-05
# Model saved at iteration 274000
# Iteration 274000 completed in 0.025523900985717773 seconds
# delta w:  3.719329833984375e-05
# Model saved at iteration 275000
# Iteration 275000 completed in 0.02518296241760254 seconds
# delta w:  5.054473876953125e-05
# Model saved at iteration 276000
# Iteration 276000 completed in 0.023835182189941406 seconds
# delta w:  5.245208740234375e-05
# Model saved at iteration 277000
# Iteration 277000 completed in 0.023594379425048828 seconds
# delta w:  6.198883056640625e-05
# Model saved at iteration 278000
# Iteration 278000 completed in 0.04540610313415527 seconds
# delta w:  6.008148193359375e-05
# Model saved at iteration 279000
# Iteration 279000 completed in 0.02379298210144043 seconds
# delta w:  5.245208740234375e-05
# Model saved at iteration 280000
# Iteration 280000 completed in 0.023483991622924805 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 281000
# Iteration 281000 completed in 0.024641990661621094 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 282000
# Iteration 282000 completed in 0.023595094680786133 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 283000
# Iteration 283000 completed in 0.02410292625427246 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 284000
# Iteration 284000 completed in 0.023509979248046875 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 285000
# Iteration 285000 completed in 0.02460503578186035 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 286000
# Iteration 286000 completed in 0.0307772159576416 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 287000
# Iteration 287000 completed in 0.032778024673461914 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 288000
# Iteration 288000 completed in 0.025942087173461914 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 289000
# Iteration 289000 completed in 0.029842853546142578 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 290000
# Iteration 290000 completed in 0.024176836013793945 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 291000
# Iteration 291000 completed in 0.023524999618530273 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 292000
# Iteration 292000 completed in 0.023874759674072266 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 293000
# Iteration 293000 completed in 0.023925065994262695 seconds
# delta w:  5.53131103515625e-05
# Model saved at iteration 294000
# Iteration 294000 completed in 0.025037050247192383 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 295000
# Iteration 295000 completed in 0.034110069274902344 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 296000
# Iteration 296000 completed in 0.024540185928344727 seconds
# delta w:  4.38690185546875e-05
# Model saved at iteration 297000
# Iteration 297000 completed in 0.026877880096435547 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 298000
# Iteration 298000 completed in 0.024036884307861328 seconds
# delta w:  5.53131103515625e-05
# Model saved at iteration 299000
# Iteration 299000 completed in 0.02655315399169922 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 300000
# Iteration 300000 completed in 0.023648977279663086 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 301000
# Iteration 301000 completed in 0.026948213577270508 seconds
# delta w:  7.43865966796875e-05
# Model saved at iteration 302000
# Iteration 302000 completed in 0.024840831756591797 seconds
# delta w:  7.05718994140625e-05
# Model saved at iteration 303000
# Iteration 303000 completed in 0.025131702423095703 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 304000
# Iteration 304000 completed in 0.02411794662475586 seconds
# delta w:  7.05718994140625e-05
# Model saved at iteration 305000
# Iteration 305000 completed in 0.024353742599487305 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 306000
# Iteration 306000 completed in 0.024897098541259766 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 307000
# Iteration 307000 completed in 0.02377009391784668 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 308000
# Iteration 308000 completed in 0.023584842681884766 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 309000
# Iteration 309000 completed in 0.024191856384277344 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 310000
# Iteration 310000 completed in 0.025386810302734375 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 311000
# Iteration 311000 completed in 0.024409055709838867 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 312000
# Iteration 312000 completed in 0.023719072341918945 seconds
# delta w:  6.67572021484375e-05
# Model saved at iteration 313000
# Iteration 313000 completed in 0.023492813110351562 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 314000
# Iteration 314000 completed in 0.027803897857666016 seconds
# delta w:  6.29425048828125e-05
# Model saved at iteration 315000
# Iteration 315000 completed in 0.023516178131103516 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 316000
# Iteration 316000 completed in 0.024947166442871094 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 317000
# Iteration 317000 completed in 0.026854753494262695 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 318000
# Iteration 318000 completed in 0.023405790328979492 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 319000
# Iteration 319000 completed in 0.023612260818481445 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 320000
# Iteration 320000 completed in 0.023399829864501953 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 321000
# Iteration 321000 completed in 0.025532007217407227 seconds
# delta w:  6.67572021484375e-05
# Model saved at iteration 322000
# Iteration 322000 completed in 0.024250030517578125 seconds
# delta w:  5.53131103515625e-05
# Model saved at iteration 323000
# Iteration 323000 completed in 0.03557991981506348 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 324000
# Iteration 324000 completed in 0.02393317222595215 seconds
# delta w:  4.00543212890625e-05
# Model saved at iteration 325000
# Iteration 325000 completed in 0.025962114334106445 seconds
# delta w:  3.814697265625e-05
# Model saved at iteration 326000
# Iteration 326000 completed in 0.03227591514587402 seconds
# delta w:  5.53131103515625e-05
# Model saved at iteration 327000
# Iteration 327000 completed in 0.02398991584777832 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 328000
# Iteration 328000 completed in 0.03815102577209473 seconds
# delta w:  7.2479248046875e-05
# Model saved at iteration 329000
# Iteration 329000 completed in 0.02489328384399414 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 330000
# Iteration 330000 completed in 0.023562192916870117 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 331000
# Iteration 331000 completed in 0.025029897689819336 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 332000
# Iteration 332000 completed in 0.025285005569458008 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 333000
# Iteration 333000 completed in 0.02413797378540039 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 334000
# Iteration 334000 completed in 0.05466794967651367 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 335000
# Iteration 335000 completed in 0.02507805824279785 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 336000
# Iteration 336000 completed in 0.0283200740814209 seconds
# delta w:  6.29425048828125e-05
# Model saved at iteration 337000
# Iteration 337000 completed in 0.0244448184967041 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 338000
# Iteration 338000 completed in 0.024274826049804688 seconds
# delta w:  4.38690185546875e-05
# Model saved at iteration 339000
# Iteration 339000 completed in 0.02982783317565918 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 340000
# Iteration 340000 completed in 0.02404618263244629 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 341000
# Iteration 341000 completed in 0.023885011672973633 seconds
# delta w:  3.814697265625e-05
# Model saved at iteration 342000
# Iteration 342000 completed in 0.02342820167541504 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 343000
# Iteration 343000 completed in 0.02436995506286621 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 344000
# Iteration 344000 completed in 0.025636672973632812 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 345000
# Iteration 345000 completed in 0.028089046478271484 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 346000
# Iteration 346000 completed in 0.023430824279785156 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 347000
# Iteration 347000 completed in 0.04087519645690918 seconds
# delta w:  6.29425048828125e-05
# Model saved at iteration 348000
# Iteration 348000 completed in 0.026892900466918945 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 349000
# Iteration 349000 completed in 0.02349090576171875 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 350000
# Iteration 350000 completed in 0.02396368980407715 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 351000
# Iteration 351000 completed in 0.023594141006469727 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 352000
# Iteration 352000 completed in 0.030791759490966797 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 353000
# Iteration 353000 completed in 0.023748159408569336 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 354000
# Iteration 354000 completed in 0.02386021614074707 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 355000
# Iteration 355000 completed in 0.024067163467407227 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 356000
# Iteration 356000 completed in 0.02434515953063965 seconds
# delta w:  7.62939453125e-05
# Model saved at iteration 357000
# Iteration 357000 completed in 0.023746967315673828 seconds
# delta w:  6.29425048828125e-05
# Model saved at iteration 358000
# Iteration 358000 completed in 0.024377822875976562 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 359000
# Iteration 359000 completed in 0.029371261596679688 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 360000
# Iteration 360000 completed in 0.024350881576538086 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 361000
# Iteration 361000 completed in 0.03448295593261719 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 362000
# Iteration 362000 completed in 0.030332088470458984 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 363000
# Iteration 363000 completed in 0.0322108268737793 seconds
# delta w:  6.4849853515625e-05
# Model saved at iteration 364000
# Iteration 364000 completed in 0.02436518669128418 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 365000
# Iteration 365000 completed in 0.02961587905883789 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 366000
# Iteration 366000 completed in 0.025789976119995117 seconds
# delta w:  5.53131103515625e-05
# Model saved at iteration 367000
# Iteration 367000 completed in 0.03589916229248047 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 368000
# Iteration 368000 completed in 0.02709817886352539 seconds
# delta w:  3.814697265625e-05
# Model saved at iteration 369000
# Iteration 369000 completed in 0.02658224105834961 seconds
# delta w:  6.29425048828125e-05
# Model saved at iteration 370000
# Iteration 370000 completed in 0.02371501922607422 seconds
# delta w:  5.53131103515625e-05
# Model saved at iteration 371000
# Iteration 371000 completed in 0.024357080459594727 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 372000
# Iteration 372000 completed in 0.023491859436035156 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 373000
# Iteration 373000 completed in 0.02342677116394043 seconds
# delta w:  7.43865966796875e-05
# Model saved at iteration 374000
# Iteration 374000 completed in 0.07124710083007812 seconds
# delta w:  6.67572021484375e-05
# Model saved at iteration 375000
# Iteration 375000 completed in 0.023906946182250977 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 376000
# Iteration 376000 completed in 0.023585081100463867 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 377000
# Iteration 377000 completed in 0.035991668701171875 seconds
# delta w:  3.814697265625e-05
# Model saved at iteration 378000
# Iteration 378000 completed in 0.02347874641418457 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 379000
# Iteration 379000 completed in 0.02402210235595703 seconds
# delta w:  7.43865966796875e-05
# Model saved at iteration 380000
# Iteration 380000 completed in 0.023648977279663086 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 381000
# Iteration 381000 completed in 0.023808956146240234 seconds
# delta w:  4.76837158203125e-05
# Model saved at iteration 382000
# Iteration 382000 completed in 0.023532867431640625 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 383000
# Iteration 383000 completed in 0.024064064025878906 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 384000
# Iteration 384000 completed in 0.02459120750427246 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 385000
# Iteration 385000 completed in 0.024238109588623047 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 386000
# Iteration 386000 completed in 0.02411794662475586 seconds
# delta w:  5.91278076171875e-05
# Model saved at iteration 387000
# Iteration 387000 completed in 0.024241924285888672 seconds
# delta w:  5.7220458984375e-05
# Model saved at iteration 388000
# Iteration 388000 completed in 0.023385047912597656 seconds
# delta w:  6.67572021484375e-05
# Model saved at iteration 389000
# Iteration 389000 completed in 0.03410696983337402 seconds
# delta w:  4.9591064453125e-05
# Model saved at iteration 390000
# Iteration 390000 completed in 0.027048826217651367 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 391000
# Iteration 391000 completed in 0.02425074577331543 seconds
# delta w:  5.53131103515625e-05
# Model saved at iteration 392000
# Iteration 392000 completed in 0.02624988555908203 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 393000
# Iteration 393000 completed in 0.02855396270751953 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 394000
# Iteration 394000 completed in 0.026166915893554688 seconds
# delta w:  5.14984130859375e-05
# Model saved at iteration 395000
# Iteration 395000 completed in 0.023990869522094727 seconds
# ...
# delta w:  6.866455078125e-05
# Model saved at iteration 1484000
# Iteration 1484000 completed in 0.03099799156188965 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1485000
# Iteration 1485000 completed in 0.03410625457763672 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1486000
# Iteration 1486000 completed in 0.0254971981048584 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1487000
# Iteration 1487000 completed in 0.04596209526062012 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1488000
# Iteration 1488000 completed in 0.024216890335083008 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1489000
# Iteration 1489000 completed in 0.023849010467529297 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1490000
# Iteration 1490000 completed in 0.02656388282775879 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1491000
# Iteration 1491000 completed in 0.024602890014648438 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1492000
# Iteration 1492000 completed in 0.03873801231384277 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1493000
# Iteration 1493000 completed in 0.03309798240661621 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1494000
# Iteration 1494000 completed in 0.027964115142822266 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1495000
# Iteration 1495000 completed in 0.02478790283203125 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1496000
# Iteration 1496000 completed in 0.034210205078125 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1497000
# Iteration 1497000 completed in 0.02339005470275879 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1498000
# Iteration 1498000 completed in 0.02980494499206543 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1499000
# Iteration 1499000 completed in 0.02455615997314453 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1500000
# Iteration 1500000 completed in 0.0234987735748291 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1501000
# Iteration 1501000 completed in 0.025829076766967773 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1502000
# Iteration 1502000 completed in 0.02364802360534668 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1503000
# Iteration 1503000 completed in 0.023999929428100586 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1504000
# Iteration 1504000 completed in 0.02353692054748535 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1505000
# Iteration 1505000 completed in 0.024584293365478516 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1506000
# Iteration 1506000 completed in 0.024280071258544922 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1507000
# Iteration 1507000 completed in 0.02358698844909668 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1508000
# Iteration 1508000 completed in 0.024908065795898438 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1509000
# Iteration 1509000 completed in 0.023551225662231445 seconds
# delta w:  7.62939453125e-05
# Model saved at iteration 1510000
# Iteration 1510000 completed in 0.0247039794921875 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1511000
# Iteration 1511000 completed in 0.023450851440429688 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1512000
# Iteration 1512000 completed in 0.0318143367767334 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1513000
# Iteration 1513000 completed in 0.025101184844970703 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1514000
# Iteration 1514000 completed in 0.024059057235717773 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1515000
# Iteration 1515000 completed in 0.023675203323364258 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1516000
# Iteration 1516000 completed in 0.023576736450195312 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1517000
# Iteration 1517000 completed in 0.023699045181274414 seconds
# delta w:  5.340576171875e-05
# Goal reached at iteration 1517644
# Model saved at iteration 1518000
# Iteration 1518000 completed in 0.023663997650146484 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1519000
# Iteration 1519000 completed in 0.023463964462280273 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1520000
# Iteration 1520000 completed in 0.03929591178894043 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1521000
# Iteration 1521000 completed in 0.17404389381408691 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1522000
# Iteration 1522000 completed in 0.0263979434967041 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1523000
# Iteration 1523000 completed in 0.02417302131652832 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1524000
# Iteration 1524000 completed in 0.033442020416259766 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1525000
# Iteration 1525000 completed in 0.0272371768951416 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1526000
# Iteration 1526000 completed in 0.02554488182067871 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1527000
# Iteration 1527000 completed in 0.023904085159301758 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1528000
# Iteration 1528000 completed in 0.023555994033813477 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1529000
# Iteration 1529000 completed in 0.031816959381103516 seconds
# delta w:  5.340576171875e-05
# Goal reached at iteration 1529530
# Model saved at iteration 1530000
# Iteration 1530000 completed in 0.0235750675201416 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1531000
# Iteration 1531000 completed in 0.02507781982421875 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1532000
# Iteration 1532000 completed in 0.027133941650390625 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1533000
# Iteration 1533000 completed in 0.023565053939819336 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1534000
# Iteration 1534000 completed in 0.023413896560668945 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1535000
# Iteration 1535000 completed in 0.02666306495666504 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1536000
# Iteration 1536000 completed in 0.030086040496826172 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1537000
# Iteration 1537000 completed in 0.023969173431396484 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1538000
# Iteration 1538000 completed in 0.023615121841430664 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1539000
# Iteration 1539000 completed in 0.024143218994140625 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1540000
# Iteration 1540000 completed in 0.023949146270751953 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1541000
# Iteration 1541000 completed in 0.0240781307220459 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1542000
# Iteration 1542000 completed in 0.025738954544067383 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1543000
# Iteration 1543000 completed in 0.023656129837036133 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1544000
# Iteration 1544000 completed in 0.024121999740600586 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1545000
# Iteration 1545000 completed in 0.02355480194091797 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1546000
# Iteration 1546000 completed in 0.02878880500793457 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1547000
# Iteration 1547000 completed in 0.024724960327148438 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1548000
# Iteration 1548000 completed in 0.025381803512573242 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1549000
# Iteration 1549000 completed in 0.026280879974365234 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1550000
# Iteration 1550000 completed in 0.023924827575683594 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1551000
# Iteration 1551000 completed in 0.024205923080444336 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1552000
# Iteration 1552000 completed in 0.024824857711791992 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1553000
# Iteration 1553000 completed in 0.03269815444946289 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1554000
# Iteration 1554000 completed in 0.023741960525512695 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1555000
# Iteration 1555000 completed in 0.023768901824951172 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1556000
# Iteration 1556000 completed in 0.02362203598022461 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1557000
# Iteration 1557000 completed in 0.023694753646850586 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1558000
# Iteration 1558000 completed in 0.024113178253173828 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1559000
# Iteration 1559000 completed in 0.023439884185791016 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1560000
# Iteration 1560000 completed in 0.02493906021118164 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1561000
# Iteration 1561000 completed in 0.02706003189086914 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1562000
# Iteration 1562000 completed in 0.025259971618652344 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1563000
# Iteration 1563000 completed in 0.027200937271118164 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1564000
# Iteration 1564000 completed in 0.02355790138244629 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1565000
# Iteration 1565000 completed in 0.023651123046875 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1566000
# Iteration 1566000 completed in 0.023508310317993164 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1567000
# Iteration 1567000 completed in 0.028456926345825195 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1568000
# Iteration 1568000 completed in 0.02390289306640625 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1569000
# Iteration 1569000 completed in 0.023550987243652344 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1570000
# Iteration 1570000 completed in 0.024137020111083984 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1571000
# Iteration 1571000 completed in 0.02368617057800293 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1572000
# Iteration 1572000 completed in 0.03643012046813965 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1573000
# Iteration 1573000 completed in 0.024062156677246094 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1574000
# Iteration 1574000 completed in 0.02349686622619629 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1575000
# Iteration 1575000 completed in 0.023668766021728516 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1576000
# Iteration 1576000 completed in 0.023437976837158203 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1577000
# Iteration 1577000 completed in 0.030881881713867188 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1578000
# Iteration 1578000 completed in 0.02900409698486328 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1579000
# Iteration 1579000 completed in 0.023806095123291016 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1580000
# Iteration 1580000 completed in 0.02376389503479004 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1581000
# Iteration 1581000 completed in 0.025136947631835938 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1582000
# Iteration 1582000 completed in 0.02356719970703125 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1583000
# Iteration 1583000 completed in 0.027956008911132812 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1584000
# Iteration 1584000 completed in 0.025539875030517578 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1585000
# Iteration 1585000 completed in 0.023651123046875 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1586000
# Iteration 1586000 completed in 0.025143146514892578 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1587000
# Iteration 1587000 completed in 0.023469924926757812 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1588000
# Iteration 1588000 completed in 0.02725815773010254 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1589000
# Iteration 1589000 completed in 0.02404618263244629 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1590000
# Iteration 1590000 completed in 0.03557705879211426 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1591000
# Iteration 1591000 completed in 0.0263822078704834 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1592000
# Iteration 1592000 completed in 0.02423882484436035 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1593000
# Iteration 1593000 completed in 0.03348374366760254 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1594000
# Iteration 1594000 completed in 0.023443937301635742 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1595000
# Iteration 1595000 completed in 0.02377796173095703 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1596000
# Iteration 1596000 completed in 0.03081798553466797 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1597000
# Iteration 1597000 completed in 0.02806711196899414 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1598000
# Iteration 1598000 completed in 0.02379918098449707 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1599000
# Iteration 1599000 completed in 0.02409195899963379 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1600000
# Iteration 1600000 completed in 0.033661842346191406 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1601000
# Iteration 1601000 completed in 0.024271249771118164 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1602000
# Iteration 1602000 completed in 0.024554014205932617 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1603000
# Iteration 1603000 completed in 0.023911237716674805 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1604000
# Iteration 1604000 completed in 0.02433323860168457 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1605000
# Iteration 1605000 completed in 0.023695945739746094 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1606000
# Iteration 1606000 completed in 0.02637505531311035 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1607000
# Iteration 1607000 completed in 0.024352073669433594 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1608000
# Iteration 1608000 completed in 0.024379968643188477 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1609000
# Iteration 1609000 completed in 0.024032115936279297 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1610000
# Iteration 1610000 completed in 0.024071931838989258 seconds
# delta w:  6.866455078125e-05
# Model saved at iteration 1611000
# Iteration 1611000 completed in 0.04262495040893555 seconds
# delta w:  4.57763671875e-05
# Model saved at iteration 1612000
# Iteration 1612000 completed in 0.02397012710571289 seconds
# delta w:  3.814697265625e-05
# Model saved at iteration 1613000
# Iteration 1613000 completed in 0.023759126663208008 seconds
# delta w:  5.340576171875e-05
# Model saved at iteration 1614000
# Iteration 1614000 completed in 0.024689912796020508 seconds
# delta w:  6.103515625e-05
# Model saved at iteration 1615000
# Iteration 1615000 completed in 0.0237576961517334 seconds
# delta w:  5.340576171875e-05
# Inf in model weights or biases
